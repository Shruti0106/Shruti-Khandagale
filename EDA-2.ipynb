# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ds = pd.read_csv("employee_dataset_for_eda.csv")
ds
# Out:
#      Employee_ID  Age  Gender   Department       Location  \
# 0           1001   50  Female    Marketing         Austin
# 1           1002   36  Female        Sales       New York
# 2           1003   29    Male    Marketing  San Francisco
# 3           1004   42  Female           HR  San Francisco
# 4           1005   40  Female    Marketing         Austin
# ..           ...  ...     ...          ...            ...
# 195         1196   40  Female           HR       New York
# 196         1197   41    Male      Finance  San Francisco
# 197         1198   53    Male           HR       New York
# 198         1199   28  Female           HR         Austin
# 199         1200   54    Male  Engineering         Austin
#
#      Years_of_Experience  Monthly_Salary  Performance_Score
# 0                      4          105046               79.6
# 1                      1           59287               71.7
# 2                      5           69711               87.2
# ...

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Employee_ID          200 non-null    int64
#  1   Age                  200 non-null    int64
#  2   Gender               200 non-null    object
#  3   Department           200 non-null    object
#  4   Location             200 non-null    object
#  5   Years_of_Experience  200 non-null    int64
#  6   Monthly_Salary       200 non-null    int64
#  7   Performance_Score    200 non-null    float64
# dtypes: float64(1), int64(4), object(3)
# memory usage: 12.6+ KB

# %%
# Employee count per department

sns.countplot(data = ds, x = 'Department', palette = 'Set2')
plt.title("Employee couont per department")
# Out:
# C:\Users\SHRUTI\AppData\Local\Temp\ipykernel_13776\1077285570.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data = ds, x = 'Department', palette = 'Set2')
# Text(0.5, 1.0, 'Employee couont per department')

# %% [markdown]
# Fianance department having more employee count followed by marketing and engineering department

# %%
# Gender Distribution

sns.countplot(data = ds, x = "Gender", palette = "coolwarm")
plt.title("Gender Distribution")
# Out:
# C:\Users\SHRUTI\AppData\Local\Temp\ipykernel_13776\1163910122.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data = ds, x = "Gender", palette = "coolwarm")
# Text(0.5, 1.0, 'Gender Distribution')

# %% [markdown]
# Female employees are more than male employees

# %%
# Employee location distribution 

sns.countplot(data = ds, x = "Location", palette = "Spectral")
plt.title("Number of Employees by distribution")
plt.xticks(rotation=45)
# Out:
# C:\Users\SHRUTI\AppData\Local\Temp\ipykernel_13776\82953330.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data = ds, x = "Location", palette = "Spectral")
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, 'Austin'),
#   Text(1, 0, 'New York'),
#   Text(2, 0, 'San Francisco'),
#   Text(3, 0, 'Seattle'),
#   Text(4, 0, 'Chicago')])

# %% [markdown]
# Seattle has more employees than New york and San Fransisco

# %%
# Age distribution

sns.histplot(ds['Age'], bins=10, kde=True)
plt.title("Age distribution")
# Out:
# Text(0.5, 1.0, 'Age distribution')

# %% [markdown]
# Employees of age between 45 to 50 are more followed by age of 25 to 30 employees

# %%
# Year of experiance

sns.histplot(ds['Years_of_Experience'], bins = 15, kde = True)
plt.title('Years of Experience')
# Out:
# Text(0.5, 1.0, 'Years of Experience')

# %%
# Monthly salary
sns.boxplot(data = ds, y='Monthly_Salary', color='lightblue')
plt.title('Monthly Salary')
# Out:
# Text(0.5, 1.0, 'Monthly Salary')

# %% [markdown]
# Minimum salary is 20,000
# Maximum salary is 1,20,000
# Middle/Avg salary is 75,000

# %%
# Average salary by department
sns.barplot(data=ds, x='Department', y='Monthly_Salary', estimator=np.mean, palette='viridis')
plt.title('Average salary by department')
# Out:
# C:\Users\SHRUTI\AppData\Local\Temp\ipykernel_13776\4148172616.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=ds, x='Department', y='Monthly_Salary', estimator=np.mean, palette='viridis')
# Text(0.5, 1.0, 'Average salary by department')

# %% [markdown]
# We can analysis the avg salary from each colored block's black line. The avg maximum salary is around 69,000 of Fianance dep and avg minimum salary is 60,000 of Sales dep.

# %%
# Performance score by department
sns.boxplot(data = ds, x='Department', y = 'Performance_Score', palette='pastel')
plt.title('Performance score by department')
# Out:
# C:\Users\SHRUTI\AppData\Local\Temp\ipykernel_13776\4258220833.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data = ds, x='Department', y = 'Performance_Score', palette='pastel')
# Text(0.5, 1.0, 'Performance score by department')

# %%
Marketing department has more performace score than

# %%
# Correlation Matrix
sns.heatmap(ds[['Age','Years_of_Experience','Monthly_Salary','Performance_Score']].corr(),annot=True,cmap='coolwarm')
plt.title('Correlation Matrix')
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %%
# Salary vs. Experience based on Department scatter plot
sns.scatterplot(data=ds, x='Years_of_Experience', y='Monthly_Salary', hue='Department')
plt.title('Salary vs. Experience based on Department')
# Out:
# Text(0.5, 1.0, 'Salary vs. Experience based on Department')

# %%
# Salary Distribution by gender
sns.violinplot(data=ds, x='Gender', y='Monthly_Salary',palette='muted')
plt.title('Salary Distribution by gender')
# Out:
# C:\Users\SHRUTI\AppData\Local\Temp\ipykernel_13776\1871332467.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=ds, x='Gender', y='Monthly_Salary',palette='muted')
# Text(0.5, 1.0, 'Salary Distribution by gender')

# %% [markdown]
# Males have more monthly salary than females
